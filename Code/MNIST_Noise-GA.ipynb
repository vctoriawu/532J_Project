# %%
#from https://medium.com/@nutanbhogendrasharma/pytorch-convolutional-neural-network-with-mnist-dataset-4e8a4265e118
import torch
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable
import numpy as np

# %%
train_data = datasets.MNIST(
    root = 'data',
    train = True,                         
    transform = ToTensor(), 
    download = True,            
)
test_data = datasets.MNIST(
    root = 'data', 
    train = False, 
    transform = ToTensor()
)

# %%
for i in range(len(train_data.data)):
    if (i % 2 == 0):
        train_data.data[i] = torch.randn(*train_data.data[i].shape)
        train_data.targets[i] = np.random.uniform(1,10)

# %%
for i in range(len(test_data.data)):
    if (i % 2 == 0):
        test_data.data[i] = torch.randn(*test_data.data[i].shape)
        test_data.targets[i] = np.random.uniform(1,10)

# %%
from torch.utils.data import DataLoader
loaders = {
    'train' : torch.utils.data.DataLoader(train_data, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
    
    'test'  : torch.utils.data.DataLoader(test_data, 
                                          batch_size=100, 
                                          shuffle=True, 
                                          num_workers=1),
}
loaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7fc0bb23e940>,
#  'test': <torch.utils.data.dataloader.DataLoader at 0x7fc0bb23e880>}

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_data), size=(1,)).item()
    img, label = train_data[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %%
import torch.nn as nn
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=1,              
                out_channels=16,            
                kernel_size=5,              
                stride=1,                   
                padding=2,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2),    
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(16, 32, 5, 1, 2),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),                
        )
        # fully connected layer, output 10 classes
        self.out = nn.Linear(32 * 7 * 7, 10)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        # flatten the output of conv2 to (batch_size, 32 * 7 * 7)
        x = x.view(x.size(0), -1)       
        output = self.out(x)
        return output, x    # return x for visualization

# %%
cnn = CNN()
print(cnn)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=1568, out_features=10, bias=True)
# )

# %%
loss_func = nn.CrossEntropyLoss()   
loss_func
# Out:
# CrossEntropyLoss()

# %%
from torch import optim
optimizer = optim.Adam(cnn.parameters(), lr = 0.01)   
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.01
#     weight_decay: 0
# )

# %%
#from https://notebook.community/Diyago/Machine-Learning-scripts/DEEP%20LEARNING/Pytorch%20from%20scratch/TODO/Autoencoders/denoising-autoencoder/Denoising_Autoencoder_Solution
num_epochs = 10
noise_factor = 1
def train(num_epochs, cnn, loaders):
    
    cnn.train()
        
    # Train the model
    total_step = len(loaders['train'])
    
    for epoch in range(num_epochs):
        for i, (images, labels) in enumerate(loaders['train']):
            correct = 0
                
            # gives batch data, normalize x when iterate train_loader
            b_x = Variable(images)   # batch x
            b_y = Variable(labels)   # batch y
            output = cnn(b_x)[0]
            loss = loss_func(output, b_y)
            
            # clear gradients for this training step   
            optimizer.zero_grad()           
            
            # backpropagation, compute gradients 
            loss.backward()    
            # apply gradients             
            optimizer.step()   
            
            pred_labels = torch.max(output, 1).indices
            correct += (pred_labels == labels).sum().item()

            if (i+1) % 100 == 0:
                accuracy = correct / len(b_y)
                print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.4f}' 
                       .format(epoch + 1, num_epochs, i + 1, total_step, loss.item(), accuracy))

train(num_epochs, cnn, loaders)
# Out:
# Epoch [1/10], Step [100/600], Loss: 1.2828, Accuracy: 0.4900
# Epoch [1/10], Step [200/600], Loss: 1.1367, Accuracy: 0.5800
# Epoch [1/10], Step [300/600], Loss: 1.1095, Accuracy: 0.5500
# Epoch [1/10], Step [400/600], Loss: 1.2089, Accuracy: 0.5400
# Epoch [1/10], Step [500/600], Loss: 1.0562, Accuracy: 0.5700
# Epoch [1/10], Step [600/600], Loss: 1.1453, Accuracy: 0.5700
# Epoch [2/10], Step [100/600], Loss: 1.1127, Accuracy: 0.5600
# Epoch [2/10], Step [200/600], Loss: 1.2264, Accuracy: 0.5100
# Epoch [2/10], Step [300/600], Loss: 1.3303, Accuracy: 0.4600
# Epoch [2/10], Step [400/600], Loss: 1.2052, Accuracy: 0.5300
# Epoch [2/10], Step [500/600], Loss: 1.2458, Accuracy: 0.4700
# Epoch [2/10], Step [600/600], Loss: 1.1423, Accuracy: 0.5600
# Epoch [3/10], Step [100/600], Loss: 1.1854, Accuracy: 0.5200
# Epoch [3/10], Step [200/600], Loss: 1.2572, Accuracy: 0.5300
# Epoch [3/10], Step [300/600], Loss: 1.2024, Accuracy: 0.5300
# Epoch [3/10], Step [400/600], Loss: 0.8761, Accuracy: 0.6800
# Epoch [3/10], Step [500/600], Loss: 1.1116, Accuracy: 0.6000
# Epoch [3/10], Step [600/600], Loss: 1.1116, Accuracy: 0.5600
# Epoch [4/10], Step [100/600], Loss: 1.1681, Accuracy: 0.5300
# Epoch [4/10], Step [200/600], Loss: 1.0490, Accuracy: 0.5500
# Epoch [4/10], Step [300/600], Loss: 1.1076, Accuracy: 0.5600
# Epoch [4/10], Step [400/600], Loss: 1.0670, Accuracy: 0.5700
# Epoch [4/10], Step [500/600], Loss: 1.0643, Accuracy: 0.5800
# Epoch [4/10], Step [600/600], Loss: 1.2175, Accuracy: 0.5100
# Epoch [5/10], Step [100/600], Loss: 1.1023, Accuracy: 0.5500
# Epoch [5/10], Step [200/600], Loss: 1.0406, Accuracy: 0.5900
# Epoch [5/10], Step [300/600], Loss: 1.1633, Accuracy: 0.5100
# Epoch [5/10], Step [400/600], Loss: 1.3898, Accuracy: 0.4100
# Epoch [5/10], Step [500/600], Loss: 1.0722, Accuracy: 0.6000
# Epoch [5/10], Step [600/600], Loss: 1.0522, Accuracy: 0.5700
# Epoch [6/10], Step [100/600], Loss: 1.0602, Accuracy: 0.6000
# Epoch [6/10], Step [200/600], Loss: 1.2573, Accuracy: 0.5100
# Epoch [6/10], Step [300/600], Loss: 1.1740, Accuracy: 0.5200
# Epoch [6/10], Step [400/600], Loss: 1.2239, Accuracy: 0.5000
# Epoch [6/10], Step [500/600], Loss: 1.2132, Accuracy: 0.5300
# Epoch [6/10], Step [600/600], Loss: 1.0019, Accuracy: 0.5700
# Epoch [7/10], Step [100/600], Loss: 1.0644, Accuracy: 0.5600
# Epoch [7/10], Step [200/600], Loss: 1.0830, Accuracy: 0.5600
# Epoch [7/10], Step [300/600], Loss: 1.0685, Accuracy: 0.5900
# Epoch [7/10], Step [400/600], Loss: 1.0711, Accuracy: 0.5800
# Epoch [7/10], Step [500/600], Loss: 1.3272, Accuracy: 0.4400
# Epoch [7/10], Step [600/600], Loss: 0.9653, Accuracy: 0.6100
# Epoch [8/10], Step [100/600], Loss: 1.0012, Accuracy: 0.5800
# Epoch [8/10], Step [200/600], Loss: 0.9478, Accuracy: 0.5900
# Epoch [8/10], Step [300/600], Loss: 1.0012, Accuracy: 0.5900
# Epoch [8/10], Step [400/600], Loss: 1.2710, Accuracy: 0.5000
# Epoch [8/10], Step [500/600], Loss: 1.2167, Accuracy: 0.5200
# Epoch [8/10], Step [600/600], Loss: 1.0556, Accuracy: 0.5600
# Epoch [9/10], Step [100/600], Loss: 1.1876, Accuracy: 0.4900
# Epoch [9/10], Step [200/600], Loss: 1.0154, Accuracy: 0.5900
# Epoch [9/10], Step [300/600], Loss: 1.1147, Accuracy: 0.5500
# Epoch [9/10], Step [400/600], Loss: 1.2230, Accuracy: 0.5000
# Epoch [9/10], Step [500/600], Loss: 1.1680, Accuracy: 0.5200
# Epoch [9/10], Step [600/600], Loss: 1.1544, Accuracy: 0.5500
# Epoch [10/10], Step [100/600], Loss: 0.9558, Accuracy: 0.6500
# Epoch [10/10], Step [200/600], Loss: 1.0866, Accuracy: 0.5500
# Epoch [10/10], Step [300/600], Loss: 1.1868, Accuracy: 0.5100
# Epoch [10/10], Step [400/600], Loss: 1.2347, Accuracy: 0.5000
# Epoch [10/10], Step [500/600], Loss: 0.9447, Accuracy: 0.6200
# Epoch [10/10], Step [600/600], Loss: 1.1395, Accuracy: 0.5300

# %%
def test():
    # Test the model
    cnn.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in loaders['test']:
            test_output, last_layer = cnn(images)
            pred_y = torch.max(test_output, 1)[1].data.squeeze()
            accuracy = (pred_y == labels).sum().item() / float(labels.size(0))

    print('Test Accuracy of the model on the 10000 test images: %.2f' % accuracy)

test()
# Out:
# Test Accuracy of the model on the 10000 test images: 0.48

# %%
#this isn't working - for some reason doing the noise by batch doesn't give good results. Figure out a better way to add noise
